# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd Practicas
# Out:
# bash: cd: Practicas: No such file or directory

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
tar -xzf base.tar.gz

# %%
mkdir Resultados

# %%
cd directorio/TLALPAN/sectorH

# %%
ls
# Out:
# names_2000-05-10.dat  names_2009-08-30.txt  names_2015-09-07.txt
# names_2000-05-24.dat  names_2009-10-06.dat  names_2015-12-24.dat
# names_2001-08-27.dat  names_2010-04-13.dat  names_2018-06-19.dat
# names_2002-04-15.txt  names_2010-11-03.txt  names_2018-08-28.dat
# names_2002-10-26.dat  names_2011-11-05.dat  names_2020-02-10.txt
# names_2005-03-21.txt  names_2012-01-03.dat  names_2020-09-13.txt
# names_2009-05-19.dat  names_2014-12-09.dat

# %%
cp names_2009-08-30.txt ../../../Resultados

# %%
cd ../../../

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd Resultados

# %%
cat < names_2009-08-30.txt > names_cat.txt

# %%
ls
# Out:
# names_2009-08-30.txt  names_cat.txt

# %%
cat names_cat.txt
# Out:
# Aguilar Natasha Alejanda	5908405556
#
# Salomon Valeria	5550562274
#
# Cedillo Arath Abijah	5957438808
#
# Lazaro Heriberto	5131681455
#
# Muñoz Maria Renee	5289217179
#
# Saldaña Francisco	5393306394
#
# Ramos Carmen Sofía	5564653521
#
# Buneder Erick Ricardo	5853411637
#
# Balandra Ana Ximena	5203278041
#
# Molina Eduardo Alberto	5736392724
#
# Barranco Carol Sthefany	5664011544
#
# Santiago Lesli Paola	5291161226
#
# Alba Anabel	5642845849
#
# Aguilar Alexia	5462563799
#
# Serralde Angel Sebastian	5522588882
#
# Yines Ana Ximena	5593340690
#
# Calette Alexia	5032726714
#
# Balmaceda Jose De	5214401999
#
# Cerezo Jesica Jocelyn	5003217550
#
# Garnica Kevin	5978399615

# %%
cat < names_2009-08-30.txt >> names_cat.txt

# %%
cat names_cat.txt
# Out:
# Aguilar Natasha Alejanda	5908405556
#
# Salomon Valeria	5550562274
#
# Cedillo Arath Abijah	5957438808
#
# Lazaro Heriberto	5131681455
#
# Muñoz Maria Renee	5289217179
#
# Saldaña Francisco	5393306394
#
# Ramos Carmen Sofía	5564653521
#
# Buneder Erick Ricardo	5853411637
#
# Balandra Ana Ximena	5203278041
#
# Molina Eduardo Alberto	5736392724
#
# Barranco Carol Sthefany	5664011544
#
# Santiago Lesli Paola	5291161226
#
# Alba Anabel	5642845849
#
# Aguilar Alexia	5462563799
#
# Serralde Angel Sebastian	5522588882
#
# Yines Ana Ximena	5593340690
#
# Calette Alexia	5032726714
#
# Balmaceda Jose De	5214401999
#
# Cerezo Jesica Jocelyn	5003217550
#
# Garnica Kevin	5978399615
#
# Aguilar Natasha Alejanda	5908405556
#
# Salomon Valeria	5550562274
#
# Cedillo Arath Abijah	5957438808
#
# Lazaro Heriberto	5131681455
#
# Muñoz Maria Renee	5289217179
#
# Saldaña Francisco	5393306394
#
# Ramos Carmen Sofía	5564653521
#
# Buneder Erick Ricardo	5853411637
#
# Balandra Ana Ximena	5203278041
#
# ...

# %%
cat names.txt 2> err.dat

# %%
cata names.txt 2> err.dat

# %%
ls
# Out:
# err.dat  names_2009-08-30.txt  names_cat.txt

# %%
cat err.dat
# Out:
# bash: cata: command not found

# %%
cat > feliz hola amigos
# Out:
# cat: hola: No such file or directory
# cat: amigos: No such file or directory

# %%
cd ..

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd directorio/COYOACAN/sectorG

# %%
ls
# Out:
# names_2000-02-18.dat  names_2005-01-29.dat  names_2013-07-19.txt
# names_2000-11-03.dat  names_2005-09-27.dat  names_2013-10-19.dat
# names_2001-08-10.txt  names_2006-10-21.dat  names_2015-01-06.txt
# names_2002-03-17.txt  names_2007-01-15.dat  names_2015-04-23.txt
# names_2002-12-09.txt  names_2007-01-22.dat  names_2015-05-23.dat
# names_2004-01-03.dat  names_2007-05-01.txt  names_2016-08-13.txt
# names_2004-03-20.dat  names_2009-12-30.txt

# %%
tac names_2005-09-27.dat
# Out:
# Lopez Martin	5270565437
#
# Penilla Emmanuel	5990448441
#
# Catalan Martha Mariana	5274177518
#
# Arredondo Jorge Alberto	5944048778
#
# Galindo Rodrigo	5292735418
#
# Calcaneo Abiram	5781375705
#
# Iturriaga Adan Israel	5210580667
#
# Rivera Yanko Salvador	5474309681
#
# Goitia Carolina	5717864060
#
# Perea Maria Jose	5841034141
#
# Piccini Andrea	5829648811
#
# Alexeev Alexia	5715139951
#
# Cruz Arath Abijah	5816462199
#
# Estrada Arturo	5636815256
#
# Icelo German	5166787251
#
# Adame Mario Arturo	5600141012
#
# Aranda Melissa	5178803725
#
# Gutierrez Maria Renee	5850364252
#
# Calle Jose Manuel	5267956463
#
# Marino Jorge Gabriel	5083218841

# %%
tac names_2005-09-27.dat > catinverso.dat

# %%
cat catinverso.dat
# Out:
# Lopez Martin	5270565437
#
# Penilla Emmanuel	5990448441
#
# Catalan Martha Mariana	5274177518
#
# Arredondo Jorge Alberto	5944048778
#
# Galindo Rodrigo	5292735418
#
# Calcaneo Abiram	5781375705
#
# Iturriaga Adan Israel	5210580667
#
# Rivera Yanko Salvador	5474309681
#
# Goitia Carolina	5717864060
#
# Perea Maria Jose	5841034141
#
# Piccini Andrea	5829648811
#
# Alexeev Alexia	5715139951
#
# Cruz Arath Abijah	5816462199
#
# Estrada Arturo	5636815256
#
# Icelo German	5166787251
#
# Adame Mario Arturo	5600141012
#
# Aranda Melissa	5178803725
#
# Gutierrez Maria Renee	5850364252
#
# Calle Jose Manuel	5267956463
#
# Marino Jorge Gabriel	5083218841

# %%
pwd
# Out:
# /home/jovyan/Practicas/directorio/COYOACAN/sectorG

# %%
ls
# Out:
# catinverso.dat        names_2004-03-20.dat  names_2009-12-30.txt
# names_2000-02-18.dat  names_2005-01-29.dat  names_2013-07-19.txt
# names_2000-11-03.dat  names_2005-09-27.dat  names_2013-10-19.dat
# names_2001-08-10.txt  names_2006-10-21.dat  names_2015-01-06.txt
# names_2002-03-17.txt  names_2007-01-15.dat  names_2015-04-23.txt
# names_2002-12-09.txt  names_2007-01-22.dat  names_2015-05-23.dat
# names_2004-01-03.dat  names_2007-05-01.txt  names_2016-08-13.txt

# %%
cp catinverso.dat ../../../Resultados

# %%
cd ../../../

# %%
cd Resultados

# %%
ls
# Out:
# catinverso.dat  err.dat  feliz  names_2009-08-30.txt  names_cat.txt

# %%
cd ..

# %%
cd directorio/CUAUHTEMOC/sectorE

# %%
ls
# Out:
# names_2001-01-14.dat  names_2009-01-19.txt  names_2016-06-13.txt
# names_2001-07-03.txt  names_2010-06-13.dat  names_2017-07-23.txt
# names_2002-04-21.dat  names_2012-02-07.txt  names_2018-06-18.txt
# names_2003-04-06.txt  names_2012-05-12.dat  names_2018-11-21.txt
# names_2005-04-09.txt  names_2012-10-13.dat  names_2020-03-07.dat
# names_2005-11-20.dat  names_2013-12-27.dat  names_2020-10-17.dat
# names_2006-07-18.txt  names_2014-01-09.txt

# %%
cat *dat *txt
# Out:
# Razo Pedro	5078328708
#
# Zavala Oscar Enrique	5349803565
#
# Arevalo Anabel	5098283547
#
# Castillo Regina	5585642291
#
# Muñoz Alexia	5670317235
#
# Molina Montserrat	5506646832
#
# Paredes Jose Manuel	5683845245
#
# Meza Jovanna Sofia	5197111714
#
# Hernandez Ana Karen	5000717497
#
# Cejudo Elsy Daniela	5571564174
#
# Sarabia Ana Ximena	5563916832
#
# Cerezo Santiago Miguel	5018574468
#
# Mendez Abiram	5908264097
#
# Vidaños Jose De	5595988687
#
# Cedillo Jesica Jocelyn	5948863480
#
# Romero Alexis	5584398354
#
# Sierra Heriberto	5497822462
#
# Contreras Logan Alexander	5021410239
#
# Munguia Luis Fernando	5120254168
#
# Orozco María Fernanda	5469440435
#
# Perez Monserrat	5856135435
#
# Ribaut Monserrat	5828687368
#
# Ponce Sofia Sarahi	5359934823
#
# Santiago Adan Israel	5283830796
#
# Molina Mario Arturo	5517047099
#
# Padilla Jesica Jocelyn	5605970802
#
# Morales Maricruz	5793512578
#
# Flores Francisco	5282546488
#
# Marzano Alexis	5186912436
#
# Alvarez Juan Yael	5882615989
# ...

# %%
cat *dat *txt > todoslosarchivos.txt

# %%
ls
# Out:
# names_2001-01-14.dat  names_2009-01-19.txt  names_2016-06-13.txt
# names_2001-07-03.txt  names_2010-06-13.dat  names_2017-07-23.txt
# names_2002-04-21.dat  names_2012-02-07.txt  names_2018-06-18.txt
# names_2003-04-06.txt  names_2012-05-12.dat  names_2018-11-21.txt
# names_2005-04-09.txt  names_2012-10-13.dat  names_2020-03-07.dat
# names_2005-11-20.dat  names_2013-12-27.dat  names_2020-10-17.dat
# names_2006-07-18.txt  names_2014-01-09.txt  todoslosarchivos.txt

# %%
cat todoslosarchivos.txt
# Out:
# Razo Pedro	5078328708
#
# Zavala Oscar Enrique	5349803565
#
# Arevalo Anabel	5098283547
#
# Castillo Regina	5585642291
#
# Muñoz Alexia	5670317235
#
# Molina Montserrat	5506646832
#
# Paredes Jose Manuel	5683845245
#
# Meza Jovanna Sofia	5197111714
#
# Hernandez Ana Karen	5000717497
#
# Cejudo Elsy Daniela	5571564174
#
# Sarabia Ana Ximena	5563916832
#
# Cerezo Santiago Miguel	5018574468
#
# Mendez Abiram	5908264097
#
# Vidaños Jose De	5595988687
#
# Cedillo Jesica Jocelyn	5948863480
#
# Romero Alexis	5584398354
#
# Sierra Heriberto	5497822462
#
# Contreras Logan Alexander	5021410239
#
# Munguia Luis Fernando	5120254168
#
# Orozco María Fernanda	5469440435
#
# Perez Monserrat	5856135435
#
# Ribaut Monserrat	5828687368
#
# Ponce Sofia Sarahi	5359934823
#
# Santiago Adan Israel	5283830796
#
# Molina Mario Arturo	5517047099
#
# Padilla Jesica Jocelyn	5605970802
#
# Morales Maricruz	5793512578
#
# Flores Francisco	5282546488
#
# Marzano Alexis	5186912436
#
# Alvarez Juan Yael	5882615989
# ...

# %%
cp todoslosarchivos.txt ../../../Resultados

# %%
cd ..

# %%
cd ..

# %%
pwd
# Out:
# /home/jovyan/Practicas/directorio

# %%
cd ..

# %%
cd Resultados

# %%
pwd
# Out:
# /home/jovyan/Practicas/Resultados

# %%
ls
# Out:
# catinverso.dat  feliz                 names_cat.txt
# err.dat         names_2009-08-30.txt  todoslosarchivos.txt

# %%
head -23 todoslosarchivos.txt > colacabeza

# %%
cat colacabeza
# Out:
# Razo Pedro	5078328708
#
# Zavala Oscar Enrique	5349803565
#
# Arevalo Anabel	5098283547
#
# Castillo Regina	5585642291
#
# Muñoz Alexia	5670317235
#
# Molina Montserrat	5506646832
#
# Paredes Jose Manuel	5683845245
#
# Meza Jovanna Sofia	5197111714
#
# Hernandez Ana Karen	5000717497
#
# Cejudo Elsy Daniela	5571564174
#
# Sarabia Ana Ximena	5563916832
#
# Cerezo Santiago Miguel	5018574468

# %%
tail -32 todoslosarchivos.txt >> colacabeza

# %%
cat -n colacabeza > colacabeza_numerada

# %%
cat colacabeza
# Out:
# Razo Pedro	5078328708
#
# Zavala Oscar Enrique	5349803565
#
# Arevalo Anabel	5098283547
#
# Castillo Regina	5585642291
#
# Muñoz Alexia	5670317235
#
# Molina Montserrat	5506646832
#
# Paredes Jose Manuel	5683845245
#
# Meza Jovanna Sofia	5197111714
#
# Hernandez Ana Karen	5000717497
#
# Cejudo Elsy Daniela	5571564174
#
# Sarabia Ana Ximena	5563916832
#
# Cerezo Santiago Miguel	5018574468
# Salomon Kevin	5859210671
#
# Lomeli Juan Yael	5606371399
#
# Mejia Ana Ximena	5706896861
#
# Morales Jose De	5615226335
#
# Andrade Vania	5655684628
#
# Maciel Herbert	5286009672
#
# Sosa Carolina	5082426744
#
# Calette Naomi	5733266185
#
# Marin German	5884175558
#
# Gutiérrez Renata Valentina	5904386257
#
# Muñoz Zahara Nahomy	5968649313
#
# Montenegro Francisco	5210874680
#
# Tinoco Mario	5155509813
#
# Herrera Martha Mariana	5786011922
#
# Medel Areli	5370268326
#
# Ochoa Rodrigo	5615030798

# %%
cat colacabeza_numerada
# Out:
#      1	Razo Pedro	5078328708
#      2
#      3	Zavala Oscar Enrique	5349803565
#      4
#      5	Arevalo Anabel	5098283547
#      6
#      7	Castillo Regina	5585642291
#      8
#      9	Muñoz Alexia	5670317235
#     10
#     11	Molina Montserrat	5506646832
#     12
#     13	Paredes Jose Manuel	5683845245
#     14
#     15	Meza Jovanna Sofia	5197111714
#     16
#     17	Hernandez Ana Karen	5000717497
#     18
#     19	Cejudo Elsy Daniela	5571564174
#     20
#     21	Sarabia Ana Ximena	5563916832
#     22
#     23	Cerezo Santiago Miguel	5018574468
#     24	Salomon Kevin	5859210671
#     25
#     26	Lomeli Juan Yael	5606371399
#     27
#     28	Mejia Ana Ximena	5706896861
#     29
#     30	Morales Jose De	5615226335
#     31
#     32	Andrade Vania	5655684628
#     33
#     34	Maciel Herbert	5286009672
#     35
#     36	Sosa Carolina	5082426744
#     37
#     38	Calette Naomi	5733266185
#     39
#     40	Marin German	5884175558
#     41
#     42	Gutiérrez Renata Valentina	5904386257
# ...

# %%
umask
# Out:
# 0022

# %%
cd Practicas

# %%
cd Resultados

# %%
umask
# Out:
# 0022

# %%
cd ..

# %%
cd Practicas/directorio/

# %%
cd Resultados
# Out:
# bash: cd: Resultados: No such file or directory

# %%
ls
# Out:
# ALVARO_OBREGON         GUSTAVO_A_MADERO        TLAHUAC
# AZCAPOTZALCO           IZTACALCO               TLALPAN
# BENITO_JUAREZ          IZTAPALAPA              VENUSTIANO_CARRANZA
# COYOACAN               LA_MAGDALENA_CONTRERAS  XOCHIMILCO
# CUAJIMALPA_DE_MORELOS  MIGUEL_HIDALGO
# CUAUHTEMOC             MILPA_ALTA

# %%
pwd
# Out:
# /home/jovyan/Practicas/directorio

# %%
cp -r /home/jovyan/Practicas/directorio/CUAUHTEMOC/ /home/jovyan/Practicas/Resultados/

# %%
pwd
# Out:
# /home/jovyan/Practicas/directorio

# %%
cd ..

# %%
cd Resultados

# %%
ls -l
# Out:
# total 44
# -rw-r--r--  1 jovyan root   597 Nov 12 04:03 catinverso.dat
# -rw-r--r--  1 jovyan root   817 Nov 12 04:03 colacabeza
# -rw-r--r--  1 jovyan root  1202 Nov 12 04:03 colacabeza_numerada
# drwxr-xr-x 13 jovyan root  4096 Nov 12 04:03 CUAUHTEMOC
# -rw-r--r--  1 jovyan root    30 Nov 12 04:03 err.dat
# -rw-r--r--  1 jovyan root     0 Nov 12 04:03 feliz
# -rw-r--r--  1 jovyan root   625 Nov 12 04:03 names_2009-08-30.txt
# -rw-r--r--  1 jovyan root  1250 Nov 12 04:03 names_cat.txt
# -rw-r--r--  1 jovyan root 12481 Nov 12 04:03 todoslosarchivos.txt

# %%
chmod 614 CUAUHTEMOC

# %%
ls -l
# Out:
# total 44
# -rw-r--r--  1 jovyan root   597 Nov 12 04:03 catinverso.dat
# -rw-r--r--  1 jovyan root   817 Nov 12 04:03 colacabeza
# -rw-r--r--  1 jovyan root  1202 Nov 12 04:03 colacabeza_numerada
# drw---xr-- 13 jovyan root  4096 Nov 12 04:03 CUAUHTEMOC
# -rw-r--r--  1 jovyan root    30 Nov 12 04:03 err.dat
# -rw-r--r--  1 jovyan root     0 Nov 12 04:03 feliz
# -rw-r--r--  1 jovyan root   625 Nov 12 04:03 names_2009-08-30.txt
# -rw-r--r--  1 jovyan root  1250 Nov 12 04:03 names_cat.txt
# -rw-r--r--  1 jovyan root 12481 Nov 12 04:03 todoslosarchivos.txt

# %%
cd CUAUHTEMOC
# Out:
# bash: cd: CUAUHTEMOC: Permission denied

# %%
ls -l CUAUHTEMOC
# Out:
# ls: cannot access 'CUAUHTEMOC/sectorJ': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorN': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorO': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorU': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorV': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorG': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorR': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorM': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorA': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorE': Permission denied
# ls: cannot access 'CUAUHTEMOC/sectorP': Permission denied
# total 0
# d????????? ? ? ? ?            ? sectorA
# d????????? ? ? ? ?            ? sectorE
# d????????? ? ? ? ?            ? sectorG
# d????????? ? ? ? ?            ? sectorJ
# d????????? ? ? ? ?            ? sectorM
# d????????? ? ? ? ?            ? sectorN
# d????????? ? ? ? ?            ? sectorO
# ...

# %%
chmod 714 CUAUHTEMOC

# %%
ls -l
# Out:
# total 44
# -rw-r--r--  1 jovyan root   597 Nov 12 04:03 catinverso.dat
# -rw-r--r--  1 jovyan root   817 Nov 12 04:03 colacabeza
# -rw-r--r--  1 jovyan root  1202 Nov 12 04:03 colacabeza_numerada
# drwx--xr-- 13 jovyan root  4096 Nov 12 04:03 CUAUHTEMOC
# -rw-r--r--  1 jovyan root    30 Nov 12 04:03 err.dat
# -rw-r--r--  1 jovyan root     0 Nov 12 04:03 feliz
# -rw-r--r--  1 jovyan root   625 Nov 12 04:03 names_2009-08-30.txt
# -rw-r--r--  1 jovyan root  1250 Nov 12 04:03 names_cat.txt
# -rw-r--r--  1 jovyan root 12481 Nov 12 04:03 todoslosarchivos.txt

# %%
cd CUAUHTEMOC

# %%
ls -l
# Out:
# total 44
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorA
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorE
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorG
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorJ
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorM
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorN
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorO
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorP
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorR
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorU
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorV

# %%
cd sectorG

# %%
ls -l
# Out:
# total 160
# -rw-r--r-- 1 jovyan root 623 Nov 12 04:03 names_2000-04-14.txt
# -rw-r--r-- 1 jovyan root 638 Nov 12 04:03 names_2001-03-03.dat
# -rw-r--r-- 1 jovyan root 626 Nov 12 04:03 names_2001-10-21.txt
# -rw-r--r-- 1 jovyan root 626 Nov 12 04:03 names_2002-01-07.txt
# -rw-r--r-- 1 jovyan root 658 Nov 12 04:03 names_2002-06-03.txt
# -rw-r--r-- 1 jovyan root 611 Nov 12 04:03 names_2002-07-31.txt
# -rw-r--r-- 1 jovyan root 608 Nov 12 04:03 names_2002-12-03.txt
# -rw-r--r-- 1 jovyan root 641 Nov 12 04:03 names_2003-06-06.txt
# -rw-r--r-- 1 jovyan root 643 Nov 12 04:03 names_2003-09-09.dat
# -rw-r--r-- 1 jovyan root 609 Nov 12 04:03 names_2005-02-27.txt
# -rw-r--r-- 1 jovyan root 628 Nov 12 04:03 names_2005-06-11.txt
# -rw-r--r-- 1 jovyan root 640 Nov 12 04:03 names_2006-08-15.txt
# -rw-r--r-- 1 jovyan root 654 Nov 12 04:03 names_2006-10-26.txt
# -rw-r--r-- 1 jovyan root 610 Nov 12 04:03 names_2007-09-06.dat
# -rw-r--r-- 1 jovyan root 633 Nov 12 04:03 names_2007-12-11.txt
# ...

# %%
chmod 740 *txt

# %%
ls -l
# Out:
# total 160
# -rwxr----- 1 jovyan root 623 Nov 12 04:03 names_2000-04-14.txt
# -rw-r--r-- 1 jovyan root 638 Nov 12 04:03 names_2001-03-03.dat
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2001-10-21.txt
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2002-01-07.txt
# -rwxr----- 1 jovyan root 658 Nov 12 04:03 names_2002-06-03.txt
# -rwxr----- 1 jovyan root 611 Nov 12 04:03 names_2002-07-31.txt
# -rwxr----- 1 jovyan root 608 Nov 12 04:03 names_2002-12-03.txt
# -rwxr----- 1 jovyan root 641 Nov 12 04:03 names_2003-06-06.txt
# -rw-r--r-- 1 jovyan root 643 Nov 12 04:03 names_2003-09-09.dat
# -rwxr----- 1 jovyan root 609 Nov 12 04:03 names_2005-02-27.txt
# -rwxr----- 1 jovyan root 628 Nov 12 04:03 names_2005-06-11.txt
# -rwxr----- 1 jovyan root 640 Nov 12 04:03 names_2006-08-15.txt
# -rwxr----- 1 jovyan root 654 Nov 12 04:03 names_2006-10-26.txt
# -rw-r--r-- 1 jovyan root 610 Nov 12 04:03 names_2007-09-06.dat
# -rwxr----- 1 jovyan root 633 Nov 12 04:03 names_2007-12-11.txt
# ...

# %%
chmod 714 *dat

# %%
ls -l
# Out:
# total 160
# -rwxr----- 1 jovyan root 623 Nov 12 04:03 names_2000-04-14.txt
# -rwx--xr-- 1 jovyan root 638 Nov 12 04:03 names_2001-03-03.dat
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2001-10-21.txt
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2002-01-07.txt
# -rwxr----- 1 jovyan root 658 Nov 12 04:03 names_2002-06-03.txt
# -rwxr----- 1 jovyan root 611 Nov 12 04:03 names_2002-07-31.txt
# -rwxr----- 1 jovyan root 608 Nov 12 04:03 names_2002-12-03.txt
# -rwxr----- 1 jovyan root 641 Nov 12 04:03 names_2003-06-06.txt
# -rwx--xr-- 1 jovyan root 643 Nov 12 04:03 names_2003-09-09.dat
# -rwxr----- 1 jovyan root 609 Nov 12 04:03 names_2005-02-27.txt
# -rwxr----- 1 jovyan root 628 Nov 12 04:03 names_2005-06-11.txt
# -rwxr----- 1 jovyan root 640 Nov 12 04:03 names_2006-08-15.txt
# -rwxr----- 1 jovyan root 654 Nov 12 04:03 names_2006-10-26.txt
# -rwx--xr-- 1 jovyan root 610 Nov 12 04:03 names_2007-09-06.dat
# -rwxr----- 1 jovyan root 633 Nov 12 04:03 names_2007-12-11.txt
# ...

# %%
ls -l > permisos.dat

# %%
cat permisos.dat
# Out:
# total 160
# -rwxr----- 1 jovyan root 623 Nov 12 04:03 names_2000-04-14.txt
# -rwx--xr-- 1 jovyan root 638 Nov 12 04:03 names_2001-03-03.dat
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2001-10-21.txt
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2002-01-07.txt
# -rwxr----- 1 jovyan root 658 Nov 12 04:03 names_2002-06-03.txt
# -rwxr----- 1 jovyan root 611 Nov 12 04:03 names_2002-07-31.txt
# -rwxr----- 1 jovyan root 608 Nov 12 04:03 names_2002-12-03.txt
# -rwxr----- 1 jovyan root 641 Nov 12 04:03 names_2003-06-06.txt
# -rwx--xr-- 1 jovyan root 643 Nov 12 04:03 names_2003-09-09.dat
# -rwxr----- 1 jovyan root 609 Nov 12 04:03 names_2005-02-27.txt
# -rwxr----- 1 jovyan root 628 Nov 12 04:03 names_2005-06-11.txt
# -rwxr----- 1 jovyan root 640 Nov 12 04:03 names_2006-08-15.txt
# -rwxr----- 1 jovyan root 654 Nov 12 04:03 names_2006-10-26.txt
# -rwx--xr-- 1 jovyan root 610 Nov 12 04:03 names_2007-09-06.dat
# -rwxr----- 1 jovyan root 633 Nov 12 04:03 names_2007-12-11.txt
# ...

# %%
pwd
# Out:
# /home/jovyan/Practicas/Resultados/CUAUHTEMOC/sectorG

# %%
cp /home/jovyan/Practicas/Resultados/CUAUHTEMOC/sectorG/permisos.dat /home/jovyan/Practicas/Resultados

# %%
pwd
# Out:
# /home/jovyan/Practicas/Resultados/CUAUHTEMOC/sectorG

# %%
cd ../../../

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd Resultados

# %%
cat permisos.dat
# Out:
# total 160
# -rwxr----- 1 jovyan root 623 Nov 12 04:03 names_2000-04-14.txt
# -rwx--xr-- 1 jovyan root 638 Nov 12 04:03 names_2001-03-03.dat
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2001-10-21.txt
# -rwxr----- 1 jovyan root 626 Nov 12 04:03 names_2002-01-07.txt
# -rwxr----- 1 jovyan root 658 Nov 12 04:03 names_2002-06-03.txt
# -rwxr----- 1 jovyan root 611 Nov 12 04:03 names_2002-07-31.txt
# -rwxr----- 1 jovyan root 608 Nov 12 04:03 names_2002-12-03.txt
# -rwxr----- 1 jovyan root 641 Nov 12 04:03 names_2003-06-06.txt
# -rwx--xr-- 1 jovyan root 643 Nov 12 04:03 names_2003-09-09.dat
# -rwxr----- 1 jovyan root 609 Nov 12 04:03 names_2005-02-27.txt
# -rwxr----- 1 jovyan root 628 Nov 12 04:03 names_2005-06-11.txt
# -rwxr----- 1 jovyan root 640 Nov 12 04:03 names_2006-08-15.txt
# -rwxr----- 1 jovyan root 654 Nov 12 04:03 names_2006-10-26.txt
# -rwx--xr-- 1 jovyan root 610 Nov 12 04:03 names_2007-09-06.dat
# -rwxr----- 1 jovyan root 633 Nov 12 04:03 names_2007-12-11.txt
# ...

# %%
cd ..

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd Resultados

# %%
cd CUAUHTEMOC

# %%
ls
# Out:
# sectorA  sectorG  sectorM  sectorO  sectorR  sectorV
# sectorE  sectorJ  sectorN  sectorP  sectorU

# %%
cd sectorP

# %%
ls
# Out:
# names_2000-03-28.dat  names_2007-12-08.dat  names_2012-08-06.dat
# names_2000-06-06.dat  names_2008-09-27.dat  names_2012-08-15.txt
# names_2000-10-02.dat  names_2008-12-05.txt  names_2012-11-28.txt
# names_2000-11-24.dat  names_2009-01-06.dat  names_2016-01-31.txt
# names_2000-11-27.dat  names_2009-08-13.txt  names_2016-02-22.txt
# names_2001-02-27.dat  names_2010-06-22.dat  names_2016-03-18.txt
# names_2001-12-09.txt  names_2010-10-12.dat  names_2016-09-02.dat
# names_2002-02-05.dat  names_2011-03-27.dat  names_2017-05-17.dat
# names_2002-08-11.dat  names_2011-04-05.dat  names_2017-08-19.dat
# names_2004-09-20.dat  names_2011-06-07.dat  names_2018-05-09.txt
# names_2006-09-19.dat  names_2011-09-21.txt  names_2018-10-10.dat
# names_2007-03-03.txt  names_2012-01-11.txt  names_2020-02-28.txt
# names_2007-07-30.txt  names_2012-01-23.dat
# names_2007-10-30.txt  names_2012-07-14.dat

# %%
ls *05-??*
# Out:
# names_2017-05-17.dat  names_2018-05-09.txt

# %%
chmod 700 *05-??*

# %%
ls -l
# Out:
# total 160
# -rw-r--r-- 1 jovyan root 643 Nov 12 04:03 names_2000-03-28.dat
# -rw-r--r-- 1 jovyan root 613 Nov 12 04:03 names_2000-06-06.dat
# -rw-r--r-- 1 jovyan root 620 Nov 12 04:03 names_2000-10-02.dat
# -rw-r--r-- 1 jovyan root 596 Nov 12 04:03 names_2000-11-24.dat
# -rw-r--r-- 1 jovyan root 605 Nov 12 04:03 names_2000-11-27.dat
# -rw-r--r-- 1 jovyan root 660 Nov 12 04:03 names_2001-02-27.dat
# -rw-r--r-- 1 jovyan root 619 Nov 12 04:03 names_2001-12-09.txt
# -rw-r--r-- 1 jovyan root 632 Nov 12 04:03 names_2002-02-05.dat
# -rw-r--r-- 1 jovyan root 612 Nov 12 04:03 names_2002-08-11.dat
# -rw-r--r-- 1 jovyan root 612 Nov 12 04:03 names_2004-09-20.dat
# -rw-r--r-- 1 jovyan root 638 Nov 12 04:03 names_2006-09-19.dat
# -rw-r--r-- 1 jovyan root 663 Nov 12 04:03 names_2007-03-03.txt
# -rw-r--r-- 1 jovyan root 600 Nov 12 04:03 names_2007-07-30.txt
# -rw-r--r-- 1 jovyan root 644 Nov 12 04:03 names_2007-10-30.txt
# -rw-r--r-- 1 jovyan root 659 Nov 12 04:03 names_2007-12-08.dat
# ...

# %%
cd ..

# %%
cd sectorO

# %%
ls
# Out:
# names_2000-08-09.dat  names_2006-02-09.txt  names_2013-10-08.dat
# names_2002-01-15.dat  names_2006-02-22.txt  names_2014-09-19.dat
# names_2003-05-04.dat  names_2009-01-12.txt  names_2015-01-31.dat
# names_2004-03-16.txt  names_2009-05-06.dat  names_2018-07-13.txt
# names_2004-04-19.dat  names_2010-01-14.txt  names_2019-02-10.txt
# names_2004-10-29.dat  names_2010-08-05.txt  names_2019-04-20.txt
# names_2005-10-07.dat  names_2011-10-02.dat

# %%
ls *??-05-??*
# Out:
# names_2003-05-04.dat  names_2009-05-06.dat

# %%
chmod 700 *??-05-??*

# %%
ls -l
# Out:
# total 80
# -rw-r--r-- 1 jovyan root 652 Nov 12 04:03 names_2000-08-09.dat
# -rw-r--r-- 1 jovyan root 617 Nov 12 04:03 names_2002-01-15.dat
# -rwx------ 1 jovyan root 618 Nov 12 04:03 names_2003-05-04.dat
# -rw-r--r-- 1 jovyan root 615 Nov 12 04:03 names_2004-03-16.txt
# -rw-r--r-- 1 jovyan root 635 Nov 12 04:03 names_2004-04-19.dat
# -rw-r--r-- 1 jovyan root 629 Nov 12 04:03 names_2004-10-29.dat
# -rw-r--r-- 1 jovyan root 633 Nov 12 04:03 names_2005-10-07.dat
# -rw-r--r-- 1 jovyan root 657 Nov 12 04:03 names_2006-02-09.txt
# -rw-r--r-- 1 jovyan root 626 Nov 12 04:03 names_2006-02-22.txt
# -rw-r--r-- 1 jovyan root 628 Nov 12 04:03 names_2009-01-12.txt
# -rwx------ 1 jovyan root 627 Nov 12 04:03 names_2009-05-06.dat
# -rw-r--r-- 1 jovyan root 619 Nov 12 04:03 names_2010-01-14.txt
# -rw-r--r-- 1 jovyan root 628 Nov 12 04:03 names_2010-08-05.txt
# -rw-r--r-- 1 jovyan root 609 Nov 12 04:03 names_2011-10-02.dat
# -rw-r--r-- 1 jovyan root 661 Nov 12 04:03 names_2013-10-08.dat
# ...

# %%
pwd
# Out:
# /home/jovyan/Practicas/Resultados/CUAUHTEMOC/sectorO

# %%
cd ../../

# %%
pwd
# Out:
# /home/jovyan/Practicas/Resultados

# %%
cd ..

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd directorio

# %%
find -name *.txt
# Out:
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2017-05-01.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2003-09-20.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2001-11-09.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2003-08-11.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2006-02-03.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2002-02-24.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2014-07-23.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2017-11-16.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2018-06-18.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2003-01-25.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2013-06-08.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2003-09-21.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2009-08-29.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2002-06-07.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2012-01-06.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2016-12-30.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2016-05-30.txt
# ./CUAJIMALPA_DE_MORELOS/sectorY/names_2020-06-24.txt
# ...

# %%
find -name *.txt | wc -l
# Out:
# 2037

# %%
find -name *.dat | wc -l
# Out:
# 2122

# %%
cd ..

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
grep -c IKer ./*/*/*.dat
# Out:
# grep: ./*/*/*.dat: No such file or directory

# %%
grep -c IKer ./*/*/*.txt
# Out:
# grep: ./*/*/*.txt: No such file or directory

# %%
find . -iname "IKer" -type f | wc -l
# Out:
# 0

# %%
grep -v "Iker" ./*/*/*.txt | wc -l
# Out:
# grep: ./*/*/*.txt: No such file or directory
# 0

# %%
grep -c "Iker" ./*/*/*.txt
# Out:
# grep: ./*/*/*.txt: No such file or directory

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
cd directorio

# %%
grep -c Iker ./*/*/*.dat/ | grep -c :0
# Out:
# grep: ./*/*/*.dat/: No such file or directory
# 0

# %%
ls | wc -l
# Out:
# 16

# %%
find . -type f | wc -l
# Out:
# 4159

# %%
find . | wc -l
# Out:
# 4346

# %%
pwd
# Out:
# /home/jovyan/Practicas/directorio

# %%
grep -r Iker /home/jovyan/Practicas/directorio | wc -l
# Out:
# 0

# %%
grep -r Iker /home/jovyan/Practicas/directorio/*/*/*2002* | wc -l
# Out:
# 0

# %%
find /home/jovyan/Practicas/directorio -type f | wc -l
# Out:
# 4159

# %%
find /home/jovyan/Practicas/directorio -type d | wc -l
# Out:
# 187

# %%
find /home/jovyan/Practicas/directorio -type f -size -1150c | wc -l
# Out:
# 4158

# %%
find /home/jovyan/Practicas/directorio/*/sectorS -name "*2020*" | wc -l
# Out:
# 8

# %%
umask
# Out:
# 0022

# %%
cd Practicas

# %%
cd Resultados

# %%
ls -la
# Out:
# total 56
# drwxr-xr-x  3 jovyan root    4096 Nov 12 04:03 .
# drwxr-xr-x  1 jovyan jovyan  4096 Nov 12 04:24 ..
# -rw-r--r--  1 jovyan root     597 Nov 12 04:03 catinverso.dat
# -rw-r--r--  1 jovyan root     817 Nov 12 04:03 colacabeza
# -rw-r--r--  1 jovyan root    1202 Nov 12 04:03 colacabeza_numerada
# drwx--xr-- 13 jovyan root    4096 Nov 12 04:03 CUAUHTEMOC
# -rw-r--r--  1 jovyan root      30 Nov 12 04:03 err.dat
# -rw-r--r--  1 jovyan root       0 Nov 12 04:03 feliz
# -rw-r--r--  1 jovyan root     625 Nov 12 04:03 names_2009-08-30.txt
# -rw-r--r--  1 jovyan root    1250 Nov 12 04:03 names_cat.txt
# -rw-r--r--  1 jovyan root    2585 Nov 12 04:03 permisos.dat
# -rw-r--r--  1 jovyan root   12481 Nov 12 04:03 todoslosarchivos.txt

# %%
cd CUAUHTEMOC

# %%
ls -l
# Out:
# total 44
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorA
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorE
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorG
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorJ
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorM
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorN
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorO
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorP
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorR
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorU
# drwxr-xr-x 2 jovyan root 4096 Nov 12 04:03 sectorV

# %%
chmod -R 614 /home/jovyan/Practicas/Resultados/CUAUHTEMOC/*/*

# %%
ls -Rla
# Out:
# .:
# total 52
# drwx--xr-- 13 jovyan root 4096 Nov 12 04:03 .
# drwxr-xr-x  3 jovyan root 4096 Nov 12 04:03 ..
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorA
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorE
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorG
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorJ
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorM
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorN
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorO
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorP
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorR
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorU
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 sectorV
#
# ./sectorA:
# total 88
# drwxr-xr-x  2 jovyan root 4096 Nov 12 04:03 .
# drwx--xr-- 13 jovyan root 4096 Nov 12 04:03 ..
# -rw---xr--  1 jovyan root  618 Nov 12 04:03 names_2000-07-13.txt
# -rw---xr--  1 jovyan root  627 Nov 12 04:03 names_2001-04-24.txt
# ...

# %%
cd ~

# %%
cd Practicas

# %%
pwd
# Out:
# /home/jovyan/Practicas

# %%
tar -czf resultado.tar.gz Resultados/
